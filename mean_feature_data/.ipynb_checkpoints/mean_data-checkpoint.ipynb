# %%
import os
import numpy as np
import tqdm
from tqdm.notebook import tqdm_notebook
import pandas as pd
import datetime

# %%
import tensorflow as tf
import tensorflow.keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from sklearn.model_selection import cross_val_score

# %%
tqdm_notebook.pandas()

# %% [markdown]
# # Train

# %%
training_folds = [1,2,3,4,6]
features = ['mfcc', 'spectogram', 'mel_spectogram', 'chroma_stft', 'chroma_cqt', 'chroma_cens', 'spectral_contrast', 'tonnetz', 'rms', 'spectral_centroid', 'spectral_bandwidth', 'spectral_flatness', 'poly_features', 'zero_crossing_rate', 'spectral_rolloff']

# %%
n_features = 0
feature_matrices = []
for feature in tqdm_notebook(features, desc = "Features loop"):
    feature_matrix = np.load(f'/Users/lizzy/Desktop/Universita/cesab/project/all_data/train_data/{feature}_matrix.npy')
    n_observations = feature_matrix.shape[0]
    if len(feature_matrix.shape) > 2:
        n_features = n_features + feature_matrix.shape[1]
    else:
        n_features = n_features + 1
        n_samples = feature_matrix.shape[1]
    feature_matrices.append(feature_matrix)
# Out:
# Features loop:   0%|          | 0/15 [00:00<?, ?it/s]

# %%
X_train = np.ndarray(shape = (n_observations, n_features))

# %%
for feature_matrix in tqdm_notebook(feature_matrices, desc = "Features loop"):
    for i in range(X_train.shape[0]):
        feature_count = 0
        if len(feature_matrix.shape) > 2:
            for j in range(feature_matrix.shape[1]):
                X_train[i, feature_count] = np.mean(feature_matrix[i, j])
                feature_count = feature_count + 1
        else:
            X_train[i, feature_count] = np.mean(feature_matrix[i])
            feature_count = feature_count + 1
# Out:
# Features loop:   0%|          | 0/15 [00:00<?, ?it/s]

# %%
y_train = np.load('/Users/lizzy/Desktop/Universita/cesab/project/all_data/train_data/training_class.json.npy')

# %% [markdown]
# # Neural Network

# %%
X_train.shape
# Out:
# (4499, 1250)

# %%
histories = []
for i in range(5):
    if i != 4:
        start = i * 1000
        stop = (i+1)*1000
        val_indices = range(start, stop)
        train_indices = [x for x in range(X_train.shape[0]) if x not in val_indices]
        X_val = X_train[val_indices]
        y_val = y_train[val_indices]
        X_train_reduced = X_train[train_indices]
        y_train_reduced = y_train[train_indices]
    else:
        X_val = X_train[4000:]
        y_val = y_train[4000:]
        X_train_reduced = X_train[:4000]
        y_train_reduced = y_train[:4000]
        
    #model    
    model = Sequential()
    model.add(layers.InputLayer(input_shape = (X_train.shape[1],)))
    for l in range(2):
        model.add(layers.Dense(30, activation='relu'))
        model.add(layers.Dense(15, activation='relu'))
        if l%2 == 0 and l != 0:
            model.add(layers.Dropout(0.1))
    model.add(layers.Dense(10, activation='softmax'))

    model.compile(optimizer='adam',
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
    #print(model.summary())

    history = model.fit(X_train_reduced,
                        y_train_reduced,
                        epochs=200,
                        batch_size = 10, 
                        validation_data = (X_val, y_val),
                        callbacks = [])
    histories.append((i, history, model))
# Out:
# Epoch 1/200
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x29f86c1f0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: unsupported operand type(s) for -: 'NoneType' and 'int'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x29f86c1f0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: unsupported operand type(s) for -: 'NoneType' and 'int'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 2021-08-30 20:05:51.507310: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2021-08-30 20:05:51.509231: W tensorflow/core/platform/profile_utils/cpu_utils.cc:126] Failed to get CPU frequency: 0 Hz
# 238/350 [===================>..........] - ETA: 0s - loss: 2.1235 - accuracy: 0.2282WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x2a2d16040> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: unsupported operand type(s) for -: 'NoneType' and 'int'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x2a2d16040> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: unsupported operand type(s) for -: 'NoneType' and 'int'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 350/350 [==============================] - 1s 1ms/step - loss: 2.0731 - accuracy: 0.2451 - val_loss: 2.0612 - val_accuracy: 0.1950
# Epoch 2/200
# 350/350 [==============================] - 0s 485us/step - loss: 1.6165 - accuracy: 0.4098 - val_loss: 2.0253 - val_accuracy: 0.2890
# Epoch 3/200
# 350/350 [==============================] - 0s 485us/step - loss: 1.4011 - accuracy: 0.4964 - val_loss: 2.0087 - val_accuracy: 0.2700
# Epoch 4/200
# 350/350 [==============================] - 0s 488us/step - loss: 1.2269 - accuracy: 0.5442 - val_loss: 2.0078 - val_accuracy: 0.3030
# Epoch 5/200
# 350/350 [==============================] - 0s 483us/step - loss: 1.1348 - accuracy: 0.5784 - val_loss: 2.1388 - val_accuracy: 0.3210
# Epoch 6/200
# 350/350 [==============================] - 0s 481us/step - loss: 1.0372 - accuracy: 0.6216 - val_loss: 2.1647 - val_accuracy: 0.3160
# Epoch 7/200
# 350/350 [==============================] - 0s 483us/step - loss: 1.0043 - accuracy: 0.6394 - val_loss: 2.4124 - val_accuracy: 0.2960
# Epoch 8/200
# 350/350 [==============================] - 0s 485us/step - loss: 0.9288 - accuracy: 0.6586 - val_loss: 2.4654 - val_accuracy: 0.2600
# Epoch 9/200
# 350/350 [==============================] - 0s 484us/step - loss: 0.8758 - accuracy: 0.6811 - val_loss: 2.5557 - val_accuracy: 0.2970
# Epoch 10/200
# 350/350 [==============================] - 0s 484us/step - loss: 0.8559 - accuracy: 0.6937 - val_loss: 2.6771 - val_accuracy: 0.3470
# Epoch 11/200
# 350/350 [==============================] - 0s 484us/step - loss: 0.8126 - accuracy: 0.7059 - val_loss: 2.8731 - val_accuracy: 0.3350
# Epoch 12/200
# 350/350 [==============================] - 0s 484us/step - loss: 0.7924 - accuracy: 0.6966 - val_loss: 2.9576 - val_accuracy: 0.3370
# Epoch 13/200
# 350/350 [==============================] - 0s 485us/step - loss: 0.7788 - accuracy: 0.7185 - val_loss: 2.8495 - val_accuracy: 0.3020
# Epoch 14/200
# 350/350 [==============================] - 0s 484us/step - loss: 0.7300 - accuracy: 0.7298 - val_loss: 2.9850 - val_accuracy: 0.3140
# Epoch 15/200
# 350/350 [==============================] - 0s 483us/step - loss: 0.6872 - accuracy: 0.7435 - val_loss: 3.3396 - val_accuracy: 0.3140
# Epoch 16/200
# 350/350 [==============================] - 0s 486us/step - loss: 0.6495 - accuracy: 0.7631 - val_loss: 3.3133 - val_accuracy: 0.3290
# Epoch 17/200
# 350/350 [==============================] - 0s 483us/step - loss: 0.6543 - accuracy: 0.7591 - val_loss: 3.0039 - val_accuracy: 0.3450
# Epoch 18/200
# 350/350 [==============================] - 0s 488us/step - loss: 0.6499 - accuracy: 0.7592 - val_loss: 3.3303 - val_accuracy: 0.3550
# Epoch 19/200
# 350/350 [==============================] - 0s 486us/step - loss: 0.6163 - accuracy: 0.7795 - val_loss: 3.2407 - val_accuracy: 0.3250
# Epoch 20/200
# 350/350 [==============================] - 0s 485us/step - loss: 0.6116 - accuracy: 0.7744 - val_loss: 3.3575 - val_accuracy: 0.3910
# Epoch 21/200
# 350/350 [==============================] - 0s 482us/step - loss: 0.6079 - accuracy: 0.7601 - val_loss: 3.5076 - val_accuracy: 0.3320
# Epoch 22/200
# 350/350 [==============================] - 0s 484us/step - loss: 0.6150 - accuracy: 0.7687 - val_loss: 3.5212 - val_accuracy: 0.3530
# Epoch 23/200
# 350/350 [==============================] - 0s 485us/step - loss: 0.5913 - accuracy: 0.7815 - val_loss: 3.7616 - val_accuracy: 0.3220
# Epoch 24/200
# 350/350 [==============================] - 0s 487us/step - loss: 0.5075 - accuracy: 0.8131 - val_loss: 3.6869 - val_accuracy: 0.3430
# Epoch 25/200
# 350/350 [==============================] - 0s 485us/step - loss: 0.5252 - accuracy: 0.8057 - val_loss: 4.4398 - val_accuracy: 0.3280
# Epoch 26/200
# 350/350 [==============================] - 0s 487us/step - loss: 0.5372 - accuracy: 0.8008 - val_loss: 3.7331 - val_accuracy: 0.3470
# Epoch 27/200
# 350/350 [==============================] - 0s 485us/step - loss: 0.5182 - accuracy: 0.8054 - val_loss: 3.8665 - val_accuracy: 0.3530
# Epoch 28/200
# 350/350 [==============================] - 0s 488us/step - loss: 0.4987 - accuracy: 0.8228 - val_loss: 3.8398 - val_accuracy: 0.3580
# Epoch 29/200
# 350/350 [==============================] - 0s 483us/step - loss: 0.4827 - accuracy: 0.8160 - val_loss: 3.9525 - val_accuracy: 0.3220
# Epoch 30/200
# 350/350 [==============================] - 0s 487us/step - loss: 0.5319 - accuracy: 0.8040 - val_loss: 4.3981 - val_accuracy: 0.3560
# Epoch 31/200
# 350/350 [==============================] - 0s 483us/step - loss: 0.4612 - accuracy: 0.8259 - val_loss: 4.5953 - val_accuracy: 0.3000
# Epoch 32/200
# 350/350 [==============================] - 0s 479us/step - loss: 0.4536 - accuracy: 0.8324 - val_loss: 4.6453 - val_accuracy: 0.3210
# Epoch 33/200
# 350/350 [==============================] - 0s 479us/step - loss: 0.4430 - accuracy: 0.8364 - val_loss: 4.3052 - val_accuracy: 0.3260
# Epoch 34/200
# 350/350 [==============================] - 0s 485us/step - loss: 0.4856 - accuracy: 0.8260 - val_loss: 4.5332 - val_accuracy: 0.3740
# Epoch 35/200
# 350/350 [==============================] - 0s 484us/step - loss: 0.4277 - accuracy: 0.8401 - val_loss: 4.3363 - val_accuracy: 0.3410
# Epoch 36/200
# 350/350 [==============================] - 0s 482us/step - loss: 0.4439 - accuracy: 0.8279 - val_loss: 4.5844 - val_accuracy: 0.3520
# Epoch 37/200
# 350/350 [==============================] - 0s 479us/step - loss: 0.4296 - accuracy: 0.8431 - val_loss: 4.2527 - val_accuracy: 0.3550
# Epoch 38/200
# 350/350 [==============================] - 0s 482us/step - loss: 0.4273 - accuracy: 0.8360 - val_loss: 4.4073 - val_accuracy: 0.3400
# Epoch 39/200
# 350/350 [==============================] - 0s 481us/step - loss: 0.4318 - accuracy: 0.8413 - val_loss: 4.4546 - val_accuracy: 0.3330
# Epoch 40/200
# 350/350 [==============================] - 0s 482us/step - loss: 0.4504 - accuracy: 0.8288 - val_loss: 4.7826 - val_accuracy: 0.3440
# Epoch 41/200
# 350/350 [==============================] - 0s 481us/step - loss: 0.4099 - accuracy: 0.8381 - val_loss: 4.5983 - val_accuracy: 0.3340
# Epoch 42/200
# 350/350 [==============================] - 0s 479us/step - loss: 0.3798 - accuracy: 0.8608 - val_loss: 4.6284 - val_accuracy: 0.3550
# Epoch 43/200
# 350/350 [==============================] - 0s 480us/step - loss: 0.4127 - accuracy: 0.8443 - val_loss: 5.8183 - val_accuracy: 0.3440
# Epoch 44/200
# 350/350 [==============================] - 0s 478us/step - loss: 0.4345 - accuracy: 0.8409 - val_loss: 5.2968 - val_accuracy: 0.3430
# Epoch 45/200
# 350/350 [==============================] - 0s 479us/step - loss: 0.4053 - accuracy: 0.8399 - val_loss: 4.9827 - val_accuracy: 0.3440
# Epoch 46/200
# 350/350 [==============================] - 0s 481us/step - loss: 0.3709 - accuracy: 0.8593 - val_loss: 5.3777 - val_accuracy: 0.3180
# Epoch 47/200
# 350/350 [==============================] - 0s 481us/step - loss: 0.4014 - accuracy: 0.8540 - val_loss: 5.9778 - val_accuracy: 0.3590
# Epoch 48/200
# 350/350 [==============================] - 0s 479us/step - loss: 0.3862 - accuracy: 0.8543 - val_loss: 5.2942 - val_accuracy: 0.3600
# Epoch 49/200
# 350/350 [==============================] - 0s 482us/step - loss: 0.3758 - accuracy: 0.8551 - val_loss: 4.9855 - val_accuracy: 0.3680
# Epoch 50/200
# 350/350 [==============================] - 0s 479us/step - loss: 0.3656 - accuracy: 0.8637 - val_loss: 5.5144 - val_accuracy: 0.3160
# Epoch 51/200
# 350/350 [==============================] - 0s 467us/step - loss: 0.3961 - accuracy: 0.8508 - val_loss: 4.9836 - val_accuracy: 0.3160
# Epoch 52/200
# 350/350 [==============================] - 0s 468us/step - loss: 0.3984 - accuracy: 0.8490 - val_loss: 5.9931 - val_accuracy: 0.3520
# Epoch 53/200
# 350/350 [==============================] - 0s 466us/step - loss: 0.3476 - accuracy: 0.8679 - val_loss: 5.5730 - val_accuracy: 0.2990
# Epoch 54/200
# 350/350 [==============================] - 0s 468us/step - loss: 0.4515 - accuracy: 0.8317 - val_loss: 5.9629 - val_accuracy: 0.3100
# Epoch 55/200
# 350/350 [==============================] - 0s 471us/step - loss: 0.3378 - accuracy: 0.8736 - val_loss: 5.8663 - val_accuracy: 0.3010
# Epoch 56/200
# 350/350 [==============================] - 0s 469us/step - loss: 0.3596 - accuracy: 0.8600 - val_loss: 5.9529 - val_accuracy: 0.3340
# Epoch 57/200
# 350/350 [==============================] - 0s 471us/step - loss: 0.3283 - accuracy: 0.8798 - val_loss: 5.3547 - val_accuracy: 0.3230
# Epoch 58/200
# 350/350 [==============================] - 0s 474us/step - loss: 0.3169 - accuracy: 0.8831 - val_loss: 5.9584 - val_accuracy: 0.3280
# Epoch 59/200
# 350/350 [==============================] - 0s 470us/step - loss: 0.3761 - accuracy: 0.8645 - val_loss: 6.0414 - val_accuracy: 0.3240
# Epoch 60/200
# 350/350 [==============================] - 0s 471us/step - loss: 0.3306 - accuracy: 0.8731 - val_loss: 5.9973 - val_accuracy: 0.3360
# Epoch 61/200
# 350/350 [==============================] - 0s 471us/step - loss: 0.3380 - accuracy: 0.8710 - val_loss: 6.1608 - val_accuracy: 0.3610
# Epoch 62/200
# 350/350 [==============================] - 0s 469us/step - loss: 0.3726 - accuracy: 0.8599 - val_loss: 5.3939 - val_accuracy: 0.3350
# Epoch 63/200
# 350/350 [==============================] - 0s 471us/step - loss: 0.3275 - accuracy: 0.8775 - val_loss: 6.2392 - val_accuracy: 0.3360
# Epoch 64/200
# 350/350 [==============================] - 0s 471us/step - loss: 0.3532 - accuracy: 0.8704 - val_loss: 6.0146 - val_accuracy: 0.3310
# Epoch 65/200
# 350/350 [==============================] - 0s 471us/step - loss: 0.3119 - accuracy: 0.8826 - val_loss: 6.2471 - val_accuracy: 0.2810
# Epoch 66/200
# 350/350 [==============================] - 0s 472us/step - loss: 0.3705 - accuracy: 0.8702 - val_loss: 5.6978 - val_accuracy: 0.3480
# Epoch 67/200
# 350/350 [==============================] - 0s 473us/step - loss: 0.3422 - accuracy: 0.8697 - val_loss: 5.2762 - val_accuracy: 0.3530
# Epoch 68/200
# 350/350 [==============================] - 0s 472us/step - loss: 0.3865 - accuracy: 0.8614 - val_loss: 6.2259 - val_accuracy: 0.3190
# Epoch 69/200
# 350/350 [==============================] - 0s 500us/step - loss: 0.2777 - accuracy: 0.8948 - val_loss: 6.4108 - val_accuracy: 0.3110
# Epoch 70/200
# 350/350 [==============================] - 0s 491us/step - loss: 0.3591 - accuracy: 0.8725 - val_loss: 6.5760 - val_accuracy: 0.3130
# Epoch 71/200
# 350/350 [==============================] - 0s 481us/step - loss: 0.2944 - accuracy: 0.8854 - val_loss: 6.6436 - val_accuracy: 0.3420
# Epoch 72/200
# 350/350 [==============================] - 0s 475us/step - loss: 0.3384 - accuracy: 0.8717 - val_loss: 6.4431 - val_accuracy: 0.3400
# Epoch 73/200
# 350/350 [==============================] - 0s 475us/step - loss: 0.3333 - accuracy: 0.8812 - val_loss: 6.5943 - val_accuracy: 0.3450
# Epoch 74/200
# 350/350 [==============================] - 0s 473us/step - loss: 0.3033 - accuracy: 0.8852 - val_loss: 6.6073 - val_accuracy: 0.3340
# Epoch 75/200
# 350/350 [==============================] - 0s 476us/step - loss: 0.3076 - accuracy: 0.8862 - val_loss: 7.0097 - val_accuracy: 0.3390
# Epoch 76/200
# 350/350 [==============================] - 0s 474us/step - loss: 0.2879 - accuracy: 0.8921 - val_loss: 6.6590 - val_accuracy: 0.3020
# Epoch 77/200
# 350/350 [==============================] - 0s 474us/step - loss: 0.2858 - accuracy: 0.8853 - val_loss: 6.8105 - val_accuracy: 0.3430
# Epoch 78/200
# 350/350 [==============================] - 0s 474us/step - loss: 0.3249 - accuracy: 0.8754 - val_loss: 6.8184 - val_accuracy: 0.3400
# Epoch 79/200
# 350/350 [==============================] - 0s 475us/step - loss: 0.2766 - accuracy: 0.8950 - val_loss: 6.6467 - val_accuracy: 0.3260
# Epoch 80/200
# 350/350 [==============================] - 0s 474us/step - loss: 0.2839 - accuracy: 0.8906 - val_loss: 6.6914 - val_accuracy: 0.3180
# Epoch 81/200
# 350/350 [==============================] - 0s 473us/step - loss: 0.3026 - accuracy: 0.8838 - val_loss: 7.7925 - val_accuracy: 0.2870
# Epoch 82/200
# 350/350 [==============================] - 0s 474us/step - loss: 0.3496 - accuracy: 0.8672 - val_loss: 6.7274 - val_accuracy: 0.2890
# Epoch 83/200
# 350/350 [==============================] - 0s 475us/step - loss: 0.2998 - accuracy: 0.8851 - val_loss: 6.7875 - val_accuracy: 0.3190
# Epoch 84/200
# 350/350 [==============================] - 0s 474us/step - loss: 0.3165 - accuracy: 0.8797 - val_loss: 6.9130 - val_accuracy: 0.3310
# Epoch 85/200
# 350/350 [==============================] - 0s 476us/step - loss: 0.2750 - accuracy: 0.8947 - val_loss: 6.7229 - val_accuracy: 0.3480
# Epoch 86/200
# 350/350 [==============================] - 0s 475us/step - loss: 0.2970 - accuracy: 0.8856 - val_loss: 6.3815 - val_accuracy: 0.3370
# Epoch 87/200
# 350/350 [==============================] - 0s 475us/step - loss: 0.3597 - accuracy: 0.8720 - val_loss: 6.9067 - val_accuracy: 0.3170
# Epoch 88/200
# 350/350 [==============================] - 0s 476us/step - loss: 0.2905 - accuracy: 0.8870 - val_loss: 6.9836 - val_accuracy: 0.3280
# Epoch 89/200
# 350/350 [==============================] - 0s 474us/step - loss: 0.2871 - accuracy: 0.8880 - val_loss: 7.2046 - val_accuracy: 0.3160
# Epoch 90/200
# 350/350 [==============================] - 0s 475us/step - loss: 0.3007 - accuracy: 0.8909 - val_loss: 7.4780 - val_accuracy: 0.3050
# Epoch 91/200
# 350/350 [==============================] - 0s 477us/step - loss: 0.3013 - accuracy: 0.8930 - val_loss: 7.5600 - val_accuracy: 0.3250
# Epoch 92/200
# 350/350 [==============================] - 0s 476us/step - loss: 0.2571 - accuracy: 0.8936 - val_loss: 7.0661 - val_accuracy: 0.3240
# Epoch 93/200
# 350/350 [==============================] - 0s 481us/step - loss: 0.3095 - accuracy: 0.8843 - val_loss: 6.7221 - val_accuracy: 0.3480
# Epoch 94/200
# 350/350 [==============================] - 0s 489us/step - loss: 0.2439 - accuracy: 0.8996 - val_loss: 7.0526 - val_accuracy: 0.3260
# Epoch 95/200
# 350/350 [==============================] - 0s 491us/step - loss: 0.2747 - accuracy: 0.8951 - val_loss: 7.7524 - val_accuracy: 0.3240
# Epoch 96/200
# 350/350 [==============================] - 0s 490us/step - loss: 0.2773 - accuracy: 0.8962 - val_loss: 7.6432 - val_accuracy: 0.3180
# Epoch 97/200
# 350/350 [==============================] - 0s 489us/step - loss: 0.2581 - accuracy: 0.8997 - val_loss: 7.2774 - val_accuracy: 0.3180
# Epoch 98/200
# 350/350 [==============================] - 0s 485us/step - loss: 0.2843 - accuracy: 0.8884 - val_loss: 9.0398 - val_accuracy: 0.3140
# Epoch 99/200
# 350/350 [==============================] - 0s 486us/step - loss: 0.2850 - accuracy: 0.8907 - val_loss: 7.6359 - val_accuracy: 0.3350
# Epoch 100/200
# 350/350 [==============================] - 0s 480us/step - loss: 0.2812 - accuracy: 0.8932 - val_loss: 7.5838 - val_accuracy: 0.3220
# Epoch 101/200
# 350/350 [==============================] - 0s 480us/step - loss: 0.2453 - accuracy: 0.8987 - val_loss: 7.2154 - val_accuracy: 0.3430
# Epoch 102/200
# 350/350 [==============================] - 0s 487us/step - loss: 0.3160 - accuracy: 0.8816 - val_loss: 7.1821 - val_accuracy: 0.3350
# Epoch 103/200
# 350/350 [==============================] - 0s 478us/step - loss: 0.2750 - accuracy: 0.8915 - val_loss: 8.0629 - val_accuracy: 0.3070
# Epoch 104/200
# 350/350 [==============================] - 0s 474us/step - loss: 0.2747 - accuracy: 0.9029 - val_loss: 8.1227 - val_accuracy: 0.3210
# Epoch 105/200
# 350/350 [==============================] - 0s 477us/step - loss: 0.3117 - accuracy: 0.8893 - val_loss: 7.5050 - val_accuracy: 0.3340
# Epoch 106/200
# 350/350 [==============================] - 0s 480us/step - loss: 0.2964 - accuracy: 0.8943 - val_loss: 7.0796 - val_accuracy: 0.3120
# Epoch 107/200
# 350/350 [==============================] - 0s 470us/step - loss: 0.2772 - accuracy: 0.8959 - val_loss: 8.0655 - val_accuracy: 0.2920
# Epoch 108/200
# 350/350 [==============================] - 0s 470us/step - loss: 0.2829 - accuracy: 0.8950 - val_loss: 7.8383 - val_accuracy: 0.3490
# Epoch 109/200
# 350/350 [==============================] - 0s 467us/step - loss: 0.2927 - accuracy: 0.8975 - val_loss: 8.0844 - val_accuracy: 0.3380
# Epoch 110/200
# 350/350 [==============================] - 0s 476us/step - loss: 0.2791 - accuracy: 0.8999 - val_loss: 8.0631 - val_accuracy: 0.3140
# Epoch 111/200
# 350/350 [==============================] - 0s 483us/step - loss: 0.2529 - accuracy: 0.8999 - val_loss: 8.0160 - val_accuracy: 0.3440
# Epoch 112/200
# 350/350 [==============================] - 0s 479us/step - loss: 0.2340 - accuracy: 0.9131 - val_loss: 7.8669 - val_accuracy: 0.2940
# Epoch 113/200
# 350/350 [==============================] - 0s 482us/step - loss: 0.2778 - accuracy: 0.8990 - val_loss: 8.2184 - val_accuracy: 0.3260
# Epoch 114/200
# 350/350 [==============================] - 0s 481us/step - loss: 0.2748 - accuracy: 0.9032 - val_loss: 7.4559 - val_accuracy: 0.3570
# Epoch 115/200
# 350/350 [==============================] - 0s 469us/step - loss: 0.3548 - accuracy: 0.8842 - val_loss: 7.8433 - val_accuracy: 0.3200
# Epoch 116/200
# 350/350 [==============================] - 0s 510us/step - loss: 0.2544 - accuracy: 0.8978 - val_loss: 7.8285 - val_accuracy: 0.3330
# Epoch 117/200
# 350/350 [==============================] - 0s 478us/step - loss: 0.2718 - accuracy: 0.8947 - val_loss: 7.7400 - val_accuracy: 0.3350
# Epoch 118/200
# 350/350 [==============================] - 0s 479us/step - loss: 0.2245 - accuracy: 0.9130 - val_loss: 8.4245 - val_accuracy: 0.3260
# Epoch 119/200
# 350/350 [==============================] - 0s 483us/step - loss: 0.2548 - accuracy: 0.9064 - val_loss: 7.6522 - val_accuracy: 0.3320
# Epoch 120/200
# 350/350 [==============================] - 0s 477us/step - loss: 0.2477 - accuracy: 0.9005 - val_loss: 8.0516 - val_accuracy: 0.3460
# Epoch 121/200
# 350/350 [==============================] - 0s 480us/step - loss: 0.2454 - accuracy: 0.9067 - val_loss: 7.5286 - val_accuracy: 0.3060
# Epoch 122/200
# 350/350 [==============================] - 0s 477us/step - loss: 0.3146 - accuracy: 0.8892 - val_loss: 8.3474 - val_accuracy: 0.3180
# Epoch 123/200
# 350/350 [==============================] - 0s 472us/step - loss: 0.2801 - accuracy: 0.9009 - val_loss: 7.1952 - val_accuracy: 0.3250
# Epoch 124/200
# 350/350 [==============================] - 0s 471us/step - loss: 0.2106 - accuracy: 0.9161 - val_loss: 8.5779 - val_accuracy: 0.2870
# Epoch 125/200
# 350/350 [==============================] - 0s 471us/step - loss: 0.2986 - accuracy: 0.8891 - val_loss: 7.3729 - val_accuracy: 0.3110
# Epoch 126/200
# 350/350 [==============================] - 0s 472us/step - loss: 0.2445 - accuracy: 0.9128 - val_loss: 8.4487 - val_accuracy: 0.3230
# Epoch 127/200
# 350/350 [==============================] - 0s 473us/step - loss: 0.2170 - accuracy: 0.9176 - val_loss: 8.8036 - val_accuracy: 0.3110
# Epoch 128/200
# 350/350 [==============================] - 0s 473us/step - loss: 0.2655 - accuracy: 0.9022 - val_loss: 7.8806 - val_accuracy: 0.2900
# Epoch 129/200
# 350/350 [==============================] - 0s 471us/step - loss: 0.2516 - accuracy: 0.9063 - val_loss: 8.6368 - val_accuracy: 0.3140
# Epoch 130/200
# 350/350 [==============================] - 0s 474us/step - loss: 0.2104 - accuracy: 0.9158 - val_loss: 8.6754 - val_accuracy: 0.3000
# Epoch 131/200
# 350/350 [==============================] - 0s 473us/step - loss: 0.2939 - accuracy: 0.8959 - val_loss: 8.1101 - val_accuracy: 0.3250
# Epoch 132/200
# 350/350 [==============================] - 0s 472us/step - loss: 0.2304 - accuracy: 0.9152 - val_loss: 8.5823 - val_accuracy: 0.3040
# Epoch 133/200
# 350/350 [==============================] - 0s 475us/step - loss: 0.2486 - accuracy: 0.9050 - val_loss: 8.2803 - val_accuracy: 0.3250
# Epoch 134/200
# 350/350 [==============================] - 0s 475us/step - loss: 0.2627 - accuracy: 0.9011 - val_loss: 8.7834 - val_accuracy: 0.3420
# Epoch 135/200
# 350/350 [==============================] - 0s 475us/step - loss: 0.2432 - accuracy: 0.9125 - val_loss: 8.5703 - val_accuracy: 0.3040
# Epoch 136/200
# 350/350 [==============================] - 0s 474us/step - loss: 0.2692 - accuracy: 0.8976 - val_loss: 8.4505 - val_accuracy: 0.3020
# Epoch 137/200
# 350/350 [==============================] - 0s 493us/step - loss: 0.2268 - accuracy: 0.9173 - val_loss: 9.5536 - val_accuracy: 0.3150
# Epoch 138/200
# 350/350 [==============================] - 0s 476us/step - loss: 0.2058 - accuracy: 0.9243 - val_loss: 8.9298 - val_accuracy: 0.3340
# Epoch 139/200
# 350/350 [==============================] - 0s 473us/step - loss: 0.2947 - accuracy: 0.8917 - val_loss: 7.9220 - val_accuracy: 0.3180
# Epoch 140/200
# 350/350 [==============================] - 0s 480us/step - loss: 0.2065 - accuracy: 0.9171 - val_loss: 8.7692 - val_accuracy: 0.3200
# Epoch 141/200
# 350/350 [==============================] - 0s 475us/step - loss: 0.2444 - accuracy: 0.9074 - val_loss: 8.0034 - val_accuracy: 0.2960
# Epoch 142/200
# 350/350 [==============================] - 0s 478us/step - loss: 0.2728 - accuracy: 0.9020 - val_loss: 9.0394 - val_accuracy: 0.2970
# Epoch 143/200
# 350/350 [==============================] - 0s 491us/step - loss: 0.2215 - accuracy: 0.9118 - val_loss: 9.2194 - val_accuracy: 0.3150
# Epoch 144/200
# 350/350 [==============================] - 0s 479us/step - loss: 0.2166 - accuracy: 0.9212 - val_loss: 10.0535 - val_accuracy: 0.3110
# Epoch 145/200
# 350/350 [==============================] - 0s 475us/step - loss: 0.2207 - accuracy: 0.9159 - val_loss: 8.5734 - val_accuracy: 0.3110
# Epoch 146/200
# 350/350 [==============================] - 0s 475us/step - loss: 0.1943 - accuracy: 0.9280 - val_loss: 9.2382 - val_accuracy: 0.3240
# Epoch 147/200
# 350/350 [==============================] - 0s 474us/step - loss: 0.2226 - accuracy: 0.9107 - val_loss: 8.8965 - val_accuracy: 0.3090
# Epoch 148/200
# 350/350 [==============================] - 0s 477us/step - loss: 0.2204 - accuracy: 0.9172 - val_loss: 8.6175 - val_accuracy: 0.3200
# Epoch 149/200
# 350/350 [==============================] - 0s 474us/step - loss: 0.3327 - accuracy: 0.8794 - val_loss: 9.5182 - val_accuracy: 0.3320
# Epoch 150/200
# 350/350 [==============================] - 0s 476us/step - loss: 0.2616 - accuracy: 0.9007 - val_loss: 8.5578 - val_accuracy: 0.3210
# Epoch 151/200
# 350/350 [==============================] - 0s 477us/step - loss: 0.2369 - accuracy: 0.9115 - val_loss: 8.8299 - val_accuracy: 0.3180
# Epoch 152/200
# 350/350 [==============================] - 0s 474us/step - loss: 0.2054 - accuracy: 0.9152 - val_loss: 9.6676 - val_accuracy: 0.3200
# Epoch 153/200
# 350/350 [==============================] - 0s 477us/step - loss: 0.2188 - accuracy: 0.9186 - val_loss: 8.9609 - val_accuracy: 0.3210
# Epoch 154/200
# 350/350 [==============================] - 0s 475us/step - loss: 0.2072 - accuracy: 0.9203 - val_loss: 9.1566 - val_accuracy: 0.3460
# Epoch 155/200
# 350/350 [==============================] - 0s 474us/step - loss: 0.2044 - accuracy: 0.9209 - val_loss: 9.6180 - val_accuracy: 0.3030
# Epoch 156/200
# 350/350 [==============================] - 0s 477us/step - loss: 0.1935 - accuracy: 0.9231 - val_loss: 8.0485 - val_accuracy: 0.3330
# Epoch 157/200
# 350/350 [==============================] - 0s 476us/step - loss: 0.2787 - accuracy: 0.8909 - val_loss: 9.0096 - val_accuracy: 0.3260
# Epoch 158/200
# 350/350 [==============================] - 0s 475us/step - loss: 0.2364 - accuracy: 0.9134 - val_loss: 9.3773 - val_accuracy: 0.3160
# Epoch 159/200
# 350/350 [==============================] - 0s 481us/step - loss: 0.2357 - accuracy: 0.9196 - val_loss: 9.7938 - val_accuracy: 0.3120
# Epoch 160/200
# 350/350 [==============================] - 0s 477us/step - loss: 0.2547 - accuracy: 0.9106 - val_loss: 9.1632 - val_accuracy: 0.3020
# Epoch 161/200
# 350/350 [==============================] - 0s 478us/step - loss: 0.1963 - accuracy: 0.9227 - val_loss: 8.8474 - val_accuracy: 0.3210
# Epoch 162/200
# 350/350 [==============================] - 0s 471us/step - loss: 0.1966 - accuracy: 0.9268 - val_loss: 9.1856 - val_accuracy: 0.3040
# Epoch 163/200
# 350/350 [==============================] - 0s 467us/step - loss: 0.2344 - accuracy: 0.9203 - val_loss: 9.4245 - val_accuracy: 0.3020
# Epoch 164/200
# 350/350 [==============================] - 0s 468us/step - loss: 0.1914 - accuracy: 0.9264 - val_loss: 9.8201 - val_accuracy: 0.3120
# Epoch 165/200
# 350/350 [==============================] - 0s 469us/step - loss: 0.1955 - accuracy: 0.9173 - val_loss: 9.5328 - val_accuracy: 0.3150
# Epoch 166/200
# 350/350 [==============================] - 0s 468us/step - loss: 0.2345 - accuracy: 0.9124 - val_loss: 9.3839 - val_accuracy: 0.3190
# Epoch 167/200
# 350/350 [==============================] - 0s 466us/step - loss: 0.2304 - accuracy: 0.9132 - val_loss: 9.7277 - val_accuracy: 0.3300
# Epoch 168/200
# 350/350 [==============================] - 0s 470us/step - loss: 0.2130 - accuracy: 0.9201 - val_loss: 10.2868 - val_accuracy: 0.3150
# Epoch 169/200
# 350/350 [==============================] - 0s 471us/step - loss: 0.2611 - accuracy: 0.9099 - val_loss: 10.5424 - val_accuracy: 0.2930
# Epoch 170/200
# 350/350 [==============================] - 0s 470us/step - loss: 0.2299 - accuracy: 0.9155 - val_loss: 10.1220 - val_accuracy: 0.2960
# Epoch 171/200
# 350/350 [==============================] - 0s 470us/step - loss: 0.2530 - accuracy: 0.9176 - val_loss: 10.2719 - val_accuracy: 0.3000
# Epoch 172/200
# 350/350 [==============================] - 0s 469us/step - loss: 0.1900 - accuracy: 0.9274 - val_loss: 10.5269 - val_accuracy: 0.2860
# Epoch 173/200
# 350/350 [==============================] - 0s 467us/step - loss: 0.2324 - accuracy: 0.9064 - val_loss: 10.7044 - val_accuracy: 0.3070
# Epoch 174/200
# 350/350 [==============================] - 0s 469us/step - loss: 0.2225 - accuracy: 0.9230 - val_loss: 10.5775 - val_accuracy: 0.3090
# Epoch 175/200
# 350/350 [==============================] - 0s 471us/step - loss: 0.1842 - accuracy: 0.9287 - val_loss: 10.2544 - val_accuracy: 0.2850
# Epoch 176/200
# 350/350 [==============================] - 0s 470us/step - loss: 0.2509 - accuracy: 0.9096 - val_loss: 9.6362 - val_accuracy: 0.3080
# Epoch 177/200
# 350/350 [==============================] - 0s 471us/step - loss: 0.2791 - accuracy: 0.9063 - val_loss: 10.7803 - val_accuracy: 0.3140
# Epoch 178/200
# 350/350 [==============================] - 0s 473us/step - loss: 0.1852 - accuracy: 0.9254 - val_loss: 10.0157 - val_accuracy: 0.3170
# Epoch 179/200
# 350/350 [==============================] - 0s 471us/step - loss: 0.2309 - accuracy: 0.9093 - val_loss: 10.0176 - val_accuracy: 0.3020
# Epoch 180/200
# 350/350 [==============================] - 0s 472us/step - loss: 0.2496 - accuracy: 0.9098 - val_loss: 10.7369 - val_accuracy: 0.3150
# Epoch 181/200
# 350/350 [==============================] - 0s 475us/step - loss: 0.1599 - accuracy: 0.9365 - val_loss: 10.3548 - val_accuracy: 0.2950
# Epoch 182/200
# 350/350 [==============================] - 0s 475us/step - loss: 0.2227 - accuracy: 0.9123 - val_loss: 11.8172 - val_accuracy: 0.2850
# Epoch 183/200
# 350/350 [==============================] - 0s 473us/step - loss: 0.1973 - accuracy: 0.9224 - val_loss: 10.0698 - val_accuracy: 0.2980
# Epoch 184/200
# 350/350 [==============================] - 0s 474us/step - loss: 0.2106 - accuracy: 0.9236 - val_loss: 10.9074 - val_accuracy: 0.3120
# Epoch 185/200
# 350/350 [==============================] - 0s 474us/step - loss: 0.2205 - accuracy: 0.9225 - val_loss: 11.4261 - val_accuracy: 0.2660
# Epoch 186/200
# 350/350 [==============================] - 0s 487us/step - loss: 0.1917 - accuracy: 0.9204 - val_loss: 11.4292 - val_accuracy: 0.3180
# Epoch 187/200
# 350/350 [==============================] - 0s 489us/step - loss: 0.2289 - accuracy: 0.9138 - val_loss: 11.1156 - val_accuracy: 0.3170
# Epoch 188/200
# 350/350 [==============================] - 0s 495us/step - loss: 0.1744 - accuracy: 0.9307 - val_loss: 11.4081 - val_accuracy: 0.3150
# Epoch 189/200
# 350/350 [==============================] - 0s 490us/step - loss: 0.1806 - accuracy: 0.9291 - val_loss: 10.2077 - val_accuracy: 0.3290
# Epoch 190/200
# 350/350 [==============================] - 0s 486us/step - loss: 0.1802 - accuracy: 0.9368 - val_loss: 11.1189 - val_accuracy: 0.3260
# Epoch 191/200
# 350/350 [==============================] - 0s 521us/step - loss: 0.1728 - accuracy: 0.9362 - val_loss: 11.2558 - val_accuracy: 0.2860
# Epoch 192/200
# 350/350 [==============================] - 0s 491us/step - loss: 0.1944 - accuracy: 0.9357 - val_loss: 12.2218 - val_accuracy: 0.2870
# Epoch 193/200
# 350/350 [==============================] - 0s 476us/step - loss: 0.2488 - accuracy: 0.9168 - val_loss: 10.5203 - val_accuracy: 0.3130
# Epoch 194/200
# 350/350 [==============================] - 0s 518us/step - loss: 0.2090 - accuracy: 0.9270 - val_loss: 10.2959 - val_accuracy: 0.3270
# Epoch 195/200
# 350/350 [==============================] - 0s 478us/step - loss: 0.1695 - accuracy: 0.9384 - val_loss: 10.1085 - val_accuracy: 0.3220
# Epoch 196/200
# 350/350 [==============================] - 0s 480us/step - loss: 0.1996 - accuracy: 0.9287 - val_loss: 10.7806 - val_accuracy: 0.2980
# Epoch 197/200
# 350/350 [==============================] - 0s 510us/step - loss: 0.1615 - accuracy: 0.9386 - val_loss: 12.0033 - val_accuracy: 0.2950
# Epoch 198/200
# 350/350 [==============================] - 0s 475us/step - loss: 0.1772 - accuracy: 0.9359 - val_loss: 11.4961 - val_accuracy: 0.2960
# Epoch 199/200
# 350/350 [==============================] - 0s 477us/step - loss: 0.1874 - accuracy: 0.9315 - val_loss: 10.8218 - val_accuracy: 0.3320
# Epoch 200/200
# 350/350 [==============================] - 0s 478us/step - loss: 0.2556 - accuracy: 0.9118 - val_loss: 11.3627 - val_accuracy: 0.3050
# Epoch 1/200
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x2a2d4cee0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: unsupported operand type(s) for -: 'NoneType' and 'int'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x2a2d4cee0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: unsupported operand type(s) for -: 'NoneType' and 'int'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 343/350 [============================>.] - ETA: 0s - loss: 2.1588 - accuracy: 0.2112WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x2a2d16a60> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: unsupported operand type(s) for -: 'NoneType' and 'int'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x2a2d16a60> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: unsupported operand type(s) for -: 'NoneType' and 'int'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 350/350 [==============================] - 0s 729us/step - loss: 2.1552 - accuracy: 0.2123 - val_loss: 2.0690 - val_accuracy: 0.2560
# Epoch 2/200
# 350/350 [==============================] - 0s 508us/step - loss: 1.6803 - accuracy: 0.3604 - val_loss: 2.1607 - val_accuracy: 0.2760
# Epoch 3/200
# 350/350 [==============================] - 0s 504us/step - loss: 1.4516 - accuracy: 0.4811 - val_loss: 2.0986 - val_accuracy: 0.2980
# Epoch 4/200
# 350/350 [==============================] - 0s 486us/step - loss: 1.2563 - accuracy: 0.5562 - val_loss: 2.2764 - val_accuracy: 0.3110
# Epoch 5/200
# 350/350 [==============================] - 0s 480us/step - loss: 1.2070 - accuracy: 0.5595 - val_loss: 2.1614 - val_accuracy: 0.3310
# Epoch 6/200
# 350/350 [==============================] - 0s 483us/step - loss: 1.0236 - accuracy: 0.6321 - val_loss: 2.1046 - val_accuracy: 0.3780
# Epoch 7/200
# 350/350 [==============================] - 0s 477us/step - loss: 0.9409 - accuracy: 0.6721 - val_loss: 2.2548 - val_accuracy: 0.3680
# Epoch 8/200
# 350/350 [==============================] - 0s 476us/step - loss: 0.9112 - accuracy: 0.6664 - val_loss: 2.4000 - val_accuracy: 0.3710
# Epoch 9/200
# 350/350 [==============================] - 0s 475us/step - loss: 0.8303 - accuracy: 0.6962 - val_loss: 2.3455 - val_accuracy: 0.3590
# Epoch 10/200
# 350/350 [==============================] - 0s 478us/step - loss: 0.7944 - accuracy: 0.7170 - val_loss: 2.4278 - val_accuracy: 0.3400
# Epoch 11/200
# 350/350 [==============================] - 0s 480us/step - loss: 0.8151 - accuracy: 0.6952 - val_loss: 2.6076 - val_accuracy: 0.3770
# Epoch 12/200
# 350/350 [==============================] - 0s 482us/step - loss: 0.7166 - accuracy: 0.7532 - val_loss: 2.8018 - val_accuracy: 0.3350
# Epoch 13/200
# 350/350 [==============================] - 0s 478us/step - loss: 0.6862 - accuracy: 0.7479 - val_loss: 2.8789 - val_accuracy: 0.3710
# Epoch 14/200
# 350/350 [==============================] - 0s 479us/step - loss: 0.6826 - accuracy: 0.7527 - val_loss: 2.6238 - val_accuracy: 0.4160
# Epoch 15/200
# 350/350 [==============================] - 0s 478us/step - loss: 0.6480 - accuracy: 0.7659 - val_loss: 2.7115 - val_accuracy: 0.3340
# Epoch 16/200
# 350/350 [==============================] - 0s 477us/step - loss: 0.6638 - accuracy: 0.7560 - val_loss: 2.9038 - val_accuracy: 0.3700
# Epoch 17/200
# 350/350 [==============================] - 0s 480us/step - loss: 0.5983 - accuracy: 0.7682 - val_loss: 2.9698 - val_accuracy: 0.3330
# Epoch 18/200
# 350/350 [==============================] - 0s 476us/step - loss: 0.6497 - accuracy: 0.7757 - val_loss: 2.8837 - val_accuracy: 0.3650
# Epoch 19/200
# 350/350 [==============================] - 0s 478us/step - loss: 0.6042 - accuracy: 0.7921 - val_loss: 3.1357 - val_accuracy: 0.2980
# Epoch 20/200
# 350/350 [==============================] - 0s 481us/step - loss: 0.5610 - accuracy: 0.7985 - val_loss: 3.0278 - val_accuracy: 0.3820
# Epoch 21/200
# 350/350 [==============================] - 0s 482us/step - loss: 0.5325 - accuracy: 0.8131 - val_loss: 3.0706 - val_accuracy: 0.3700
# Epoch 22/200
# 350/350 [==============================] - 0s 482us/step - loss: 0.5374 - accuracy: 0.8073 - val_loss: 3.3745 - val_accuracy: 0.3400
# Epoch 23/200
# 350/350 [==============================] - 0s 480us/step - loss: 0.5137 - accuracy: 0.8126 - val_loss: 2.9271 - val_accuracy: 0.3760
# Epoch 24/200
# 350/350 [==============================] - 0s 481us/step - loss: 0.4990 - accuracy: 0.8222 - val_loss: 3.4447 - val_accuracy: 0.3740
# Epoch 25/200
# 350/350 [==============================] - 0s 476us/step - loss: 0.4585 - accuracy: 0.8276 - val_loss: 3.2342 - val_accuracy: 0.3980
# Epoch 26/200
# 350/350 [==============================] - 0s 479us/step - loss: 0.4750 - accuracy: 0.8268 - val_loss: 3.3850 - val_accuracy: 0.3780
# Epoch 27/200
# 350/350 [==============================] - 0s 478us/step - loss: 0.4672 - accuracy: 0.8279 - val_loss: 3.2787 - val_accuracy: 0.3480
# Epoch 28/200
# 350/350 [==============================] - 0s 476us/step - loss: 0.4748 - accuracy: 0.8222 - val_loss: 3.7207 - val_accuracy: 0.3530
# Epoch 29/200
# 350/350 [==============================] - 0s 479us/step - loss: 0.4434 - accuracy: 0.8399 - val_loss: 3.5248 - val_accuracy: 0.4040
# Epoch 30/200
# 350/350 [==============================] - 0s 477us/step - loss: 0.4414 - accuracy: 0.8361 - val_loss: 3.5167 - val_accuracy: 0.3840
# Epoch 31/200
# 350/350 [==============================] - 0s 479us/step - loss: 0.4437 - accuracy: 0.8402 - val_loss: 3.6640 - val_accuracy: 0.3650
# Epoch 32/200
# 350/350 [==============================] - 0s 480us/step - loss: 0.4209 - accuracy: 0.8467 - val_loss: 3.6001 - val_accuracy: 0.3690
# Epoch 33/200
# 350/350 [==============================] - 0s 477us/step - loss: 0.4490 - accuracy: 0.8319 - val_loss: 3.5150 - val_accuracy: 0.3850
# Epoch 34/200
# 350/350 [==============================] - 0s 478us/step - loss: 0.4221 - accuracy: 0.8357 - val_loss: 3.3431 - val_accuracy: 0.4190
# Epoch 35/200
# 350/350 [==============================] - 0s 513us/step - loss: 0.3958 - accuracy: 0.8558 - val_loss: 3.9090 - val_accuracy: 0.3520
# Epoch 36/200
# 350/350 [==============================] - 0s 501us/step - loss: 0.3697 - accuracy: 0.8649 - val_loss: 4.0027 - val_accuracy: 0.3840
# Epoch 37/200
# 350/350 [==============================] - 0s 484us/step - loss: 0.4372 - accuracy: 0.8436 - val_loss: 4.2919 - val_accuracy: 0.3710
# Epoch 38/200
# 350/350 [==============================] - 0s 480us/step - loss: 0.4635 - accuracy: 0.8343 - val_loss: 3.7093 - val_accuracy: 0.4180
# Epoch 39/200
# 350/350 [==============================] - 0s 551us/step - loss: 0.4088 - accuracy: 0.8460 - val_loss: 4.2116 - val_accuracy: 0.3490
# Epoch 40/200
# 350/350 [==============================] - 0s 496us/step - loss: 0.3905 - accuracy: 0.8556 - val_loss: 4.2211 - val_accuracy: 0.3770
# Epoch 41/200
# 350/350 [==============================] - 0s 484us/step - loss: 0.3774 - accuracy: 0.8538 - val_loss: 4.7691 - val_accuracy: 0.2970
# Epoch 42/200
# 350/350 [==============================] - 0s 483us/step - loss: 0.4207 - accuracy: 0.8485 - val_loss: 4.2377 - val_accuracy: 0.3560
# Epoch 43/200
# 350/350 [==============================] - 0s 482us/step - loss: 0.3771 - accuracy: 0.8650 - val_loss: 3.9788 - val_accuracy: 0.3840
# Epoch 44/200
# 350/350 [==============================] - 0s 481us/step - loss: 0.3805 - accuracy: 0.8625 - val_loss: 4.5021 - val_accuracy: 0.3650
# Epoch 45/200
# 350/350 [==============================] - 0s 481us/step - loss: 0.3363 - accuracy: 0.8768 - val_loss: 4.4497 - val_accuracy: 0.3990
# Epoch 46/200
# 350/350 [==============================] - 0s 479us/step - loss: 0.3405 - accuracy: 0.8724 - val_loss: 4.5780 - val_accuracy: 0.3870
# Epoch 47/200
# 350/350 [==============================] - 0s 482us/step - loss: 0.3463 - accuracy: 0.8675 - val_loss: 4.4854 - val_accuracy: 0.4080
# Epoch 48/200
# 350/350 [==============================] - 0s 481us/step - loss: 0.3530 - accuracy: 0.8772 - val_loss: 5.1245 - val_accuracy: 0.3810
# Epoch 49/200
# 350/350 [==============================] - 0s 482us/step - loss: 0.3471 - accuracy: 0.8712 - val_loss: 4.4051 - val_accuracy: 0.3960
# Epoch 50/200
# 350/350 [==============================] - 0s 481us/step - loss: 0.3470 - accuracy: 0.8786 - val_loss: 4.6410 - val_accuracy: 0.3420
# Epoch 51/200
# 350/350 [==============================] - 0s 481us/step - loss: 0.3556 - accuracy: 0.8738 - val_loss: 4.6183 - val_accuracy: 0.3530
# Epoch 52/200
# 350/350 [==============================] - 0s 478us/step - loss: 0.3597 - accuracy: 0.8678 - val_loss: 4.4593 - val_accuracy: 0.4000
# Epoch 53/200
# 350/350 [==============================] - 0s 479us/step - loss: 0.3003 - accuracy: 0.8872 - val_loss: 4.5258 - val_accuracy: 0.3610
# Epoch 54/200
# 350/350 [==============================] - 0s 482us/step - loss: 0.3306 - accuracy: 0.8765 - val_loss: 4.7906 - val_accuracy: 0.3890
# Epoch 55/200
# 350/350 [==============================] - 0s 489us/step - loss: 0.3041 - accuracy: 0.8846 - val_loss: 4.5801 - val_accuracy: 0.3480
# Epoch 56/200
# 350/350 [==============================] - 0s 480us/step - loss: 0.3264 - accuracy: 0.8799 - val_loss: 4.8861 - val_accuracy: 0.3340
# Epoch 57/200
# 350/350 [==============================] - 0s 493us/step - loss: 0.3159 - accuracy: 0.8746 - val_loss: 4.8472 - val_accuracy: 0.3930
# Epoch 58/200
# 350/350 [==============================] - 0s 525us/step - loss: 0.2750 - accuracy: 0.8993 - val_loss: 4.7203 - val_accuracy: 0.3800
# Epoch 59/200
# 350/350 [==============================] - 0s 481us/step - loss: 0.3598 - accuracy: 0.8665 - val_loss: 5.2031 - val_accuracy: 0.3500
# Epoch 60/200
# 350/350 [==============================] - 0s 502us/step - loss: 0.3702 - accuracy: 0.8631 - val_loss: 4.7201 - val_accuracy: 0.3720
# Epoch 61/200
# 350/350 [==============================] - 0s 497us/step - loss: 0.3076 - accuracy: 0.8879 - val_loss: 5.0011 - val_accuracy: 0.3700
# Epoch 62/200
# 350/350 [==============================] - 0s 499us/step - loss: 0.3149 - accuracy: 0.8808 - val_loss: 5.3185 - val_accuracy: 0.3480
# Epoch 63/200
# 350/350 [==============================] - 0s 513us/step - loss: 0.3131 - accuracy: 0.8920 - val_loss: 5.1991 - val_accuracy: 0.3340
# Epoch 64/200
# 350/350 [==============================] - 0s 502us/step - loss: 0.3177 - accuracy: 0.8833 - val_loss: 5.1686 - val_accuracy: 0.3790
# Epoch 65/200
# 350/350 [==============================] - 0s 505us/step - loss: 0.3150 - accuracy: 0.8876 - val_loss: 5.0874 - val_accuracy: 0.3440
# Epoch 66/200
# 350/350 [==============================] - 0s 510us/step - loss: 0.2673 - accuracy: 0.8999 - val_loss: 5.1555 - val_accuracy: 0.3790
# Epoch 67/200
# 350/350 [==============================] - 0s 481us/step - loss: 0.3489 - accuracy: 0.8794 - val_loss: 5.3963 - val_accuracy: 0.3600
# Epoch 68/200
# 350/350 [==============================] - 0s 503us/step - loss: 0.2634 - accuracy: 0.9028 - val_loss: 5.4646 - val_accuracy: 0.3800
# Epoch 69/200
# 350/350 [==============================] - 0s 501us/step - loss: 0.2953 - accuracy: 0.9005 - val_loss: 5.4282 - val_accuracy: 0.3230
# Epoch 70/200
# 350/350 [==============================] - 0s 501us/step - loss: 0.3250 - accuracy: 0.8777 - val_loss: 5.7573 - val_accuracy: 0.3810
# Epoch 71/200
# 350/350 [==============================] - 0s 507us/step - loss: 0.2929 - accuracy: 0.8924 - val_loss: 5.3245 - val_accuracy: 0.3960
# Epoch 72/200
# 350/350 [==============================] - 0s 492us/step - loss: 0.2938 - accuracy: 0.8922 - val_loss: 5.8279 - val_accuracy: 0.3500
# Epoch 73/200
# 350/350 [==============================] - 0s 473us/step - loss: 0.2678 - accuracy: 0.8999 - val_loss: 5.2569 - val_accuracy: 0.3960
# Epoch 74/200
# 350/350 [==============================] - 0s 476us/step - loss: 0.3514 - accuracy: 0.8665 - val_loss: 5.0296 - val_accuracy: 0.4150
# Epoch 75/200
# 350/350 [==============================] - 0s 508us/step - loss: 0.2868 - accuracy: 0.8957 - val_loss: 5.5653 - val_accuracy: 0.4070
# Epoch 76/200
# 350/350 [==============================] - 0s 499us/step - loss: 0.2881 - accuracy: 0.8894 - val_loss: 5.4320 - val_accuracy: 0.3920
# Epoch 77/200
# 350/350 [==============================] - 0s 499us/step - loss: 0.2598 - accuracy: 0.9085 - val_loss: 5.1161 - val_accuracy: 0.3690
# Epoch 78/200
# 350/350 [==============================] - 0s 501us/step - loss: 0.2703 - accuracy: 0.8979 - val_loss: 5.6920 - val_accuracy: 0.3810
# Epoch 79/200
# 350/350 [==============================] - 0s 492us/step - loss: 0.3268 - accuracy: 0.8830 - val_loss: 5.6112 - val_accuracy: 0.3720
# Epoch 80/200
# 350/350 [==============================] - 0s 511us/step - loss: 0.2890 - accuracy: 0.8959 - val_loss: 5.7069 - val_accuracy: 0.3750
# Epoch 81/200
# 350/350 [==============================] - 0s 502us/step - loss: 0.2587 - accuracy: 0.9077 - val_loss: 5.6418 - val_accuracy: 0.3610
# Epoch 82/200
# 350/350 [==============================] - 0s 502us/step - loss: 0.2404 - accuracy: 0.9069 - val_loss: 5.6086 - val_accuracy: 0.3880
# Epoch 83/200
# 350/350 [==============================] - 0s 480us/step - loss: 0.2620 - accuracy: 0.9049 - val_loss: 5.9356 - val_accuracy: 0.3150
# Epoch 84/200
# 350/350 [==============================] - 0s 495us/step - loss: 0.2616 - accuracy: 0.9025 - val_loss: 6.6900 - val_accuracy: 0.3710
# Epoch 85/200
# 350/350 [==============================] - 0s 492us/step - loss: 0.2522 - accuracy: 0.9036 - val_loss: 6.2355 - val_accuracy: 0.3460
# Epoch 86/200
# 350/350 [==============================] - 0s 490us/step - loss: 0.3537 - accuracy: 0.8744 - val_loss: 5.6770 - val_accuracy: 0.4110
# Epoch 87/200
# 350/350 [==============================] - 0s 487us/step - loss: 0.2628 - accuracy: 0.8995 - val_loss: 5.3139 - val_accuracy: 0.3780
# Epoch 88/200
# 350/350 [==============================] - 0s 487us/step - loss: 0.2560 - accuracy: 0.9041 - val_loss: 6.0419 - val_accuracy: 0.3820
# Epoch 89/200
# 350/350 [==============================] - 0s 488us/step - loss: 0.2858 - accuracy: 0.8895 - val_loss: 5.9534 - val_accuracy: 0.3580
# Epoch 90/200
# 350/350 [==============================] - 0s 484us/step - loss: 0.2776 - accuracy: 0.9045 - val_loss: 5.4765 - val_accuracy: 0.3860
# Epoch 91/200
# 350/350 [==============================] - 0s 482us/step - loss: 0.2513 - accuracy: 0.9030 - val_loss: 6.1781 - val_accuracy: 0.3490
# Epoch 92/200
# 350/350 [==============================] - 0s 480us/step - loss: 0.2616 - accuracy: 0.8982 - val_loss: 6.0754 - val_accuracy: 0.3730
# Epoch 93/200
# 350/350 [==============================] - 0s 495us/step - loss: 0.3178 - accuracy: 0.8808 - val_loss: 6.0864 - val_accuracy: 0.3770
# Epoch 94/200
# 350/350 [==============================] - 0s 494us/step - loss: 0.2659 - accuracy: 0.8940 - val_loss: 5.8176 - val_accuracy: 0.3920
# Epoch 95/200
# 350/350 [==============================] - 0s 489us/step - loss: 0.2867 - accuracy: 0.8895 - val_loss: 5.8363 - val_accuracy: 0.3790
# Epoch 96/200
# 350/350 [==============================] - 0s 490us/step - loss: 0.2510 - accuracy: 0.9116 - val_loss: 5.6664 - val_accuracy: 0.3890
# Epoch 97/200
# 350/350 [==============================] - 0s 489us/step - loss: 0.2600 - accuracy: 0.9059 - val_loss: 6.5331 - val_accuracy: 0.3660
# Epoch 98/200
# 350/350 [==============================] - 0s 525us/step - loss: 0.2547 - accuracy: 0.9080 - val_loss: 6.2694 - val_accuracy: 0.3750
# Epoch 99/200
# 350/350 [==============================] - 0s 481us/step - loss: 0.2659 - accuracy: 0.8976 - val_loss: 6.1042 - val_accuracy: 0.3820
# Epoch 100/200
# ...
# Epoch 93/200
# 400/400 [==============================] - 0s 441us/step - loss: 0.2957 - accuracy: 0.8922 - val_loss: 5.2099 - val_accuracy: 0.3948
# Epoch 94/200
# 400/400 [==============================] - 0s 442us/step - loss: 0.2718 - accuracy: 0.8972 - val_loss: 5.1336 - val_accuracy: 0.4309
# Epoch 95/200
# 400/400 [==============================] - 0s 444us/step - loss: 0.2613 - accuracy: 0.8965 - val_loss: 5.0982 - val_accuracy: 0.3687
# Epoch 96/200
# 400/400 [==============================] - 0s 442us/step - loss: 0.3073 - accuracy: 0.8835 - val_loss: 5.4068 - val_accuracy: 0.3467
# Epoch 97/200
# 400/400 [==============================] - 0s 447us/step - loss: 0.2681 - accuracy: 0.8940 - val_loss: 5.2556 - val_accuracy: 0.4309
# Epoch 98/200
# 400/400 [==============================] - 0s 445us/step - loss: 0.2492 - accuracy: 0.9087 - val_loss: 5.8247 - val_accuracy: 0.3788
# Epoch 99/200
# 400/400 [==============================] - 0s 442us/step - loss: 0.2956 - accuracy: 0.8852 - val_loss: 5.8791 - val_accuracy: 0.3908
# Epoch 100/200
# 400/400 [==============================] - 0s 443us/step - loss: 0.2715 - accuracy: 0.8975 - val_loss: 6.1468 - val_accuracy: 0.4028
# Epoch 101/200
# 400/400 [==============================] - 0s 445us/step - loss: 0.2721 - accuracy: 0.8946 - val_loss: 5.3363 - val_accuracy: 0.4008
# Epoch 102/200
# 400/400 [==============================] - 0s 444us/step - loss: 0.3160 - accuracy: 0.8766 - val_loss: 6.3507 - val_accuracy: 0.4369
# Epoch 103/200
# 400/400 [==============================] - 0s 443us/step - loss: 0.2457 - accuracy: 0.9057 - val_loss: 5.6286 - val_accuracy: 0.4188
# Epoch 104/200
# 400/400 [==============================] - 0s 444us/step - loss: 0.2653 - accuracy: 0.9003 - val_loss: 5.8568 - val_accuracy: 0.4088
# Epoch 105/200
# 400/400 [==============================] - 0s 444us/step - loss: 0.2483 - accuracy: 0.9073 - val_loss: 5.9953 - val_accuracy: 0.4248
# Epoch 106/200
# 400/400 [==============================] - 0s 445us/step - loss: 0.2929 - accuracy: 0.8849 - val_loss: 5.3354 - val_accuracy: 0.3908
# Epoch 107/200
# 400/400 [==============================] - 0s 445us/step - loss: 0.2738 - accuracy: 0.8947 - val_loss: 5.8391 - val_accuracy: 0.4148
# Epoch 108/200
# 400/400 [==============================] - 0s 448us/step - loss: 0.3217 - accuracy: 0.8924 - val_loss: 5.7899 - val_accuracy: 0.4208
# Epoch 109/200
# 400/400 [==============================] - 0s 445us/step - loss: 0.2618 - accuracy: 0.9036 - val_loss: 5.4124 - val_accuracy: 0.4048
# Epoch 110/200
# 400/400 [==============================] - 0s 447us/step - loss: 0.2465 - accuracy: 0.9033 - val_loss: 5.5185 - val_accuracy: 0.3487
# Epoch 111/200
# 400/400 [==============================] - 0s 446us/step - loss: 0.2725 - accuracy: 0.8970 - val_loss: 5.0866 - val_accuracy: 0.3868
# Epoch 112/200
# 400/400 [==============================] - 0s 447us/step - loss: 0.2431 - accuracy: 0.9063 - val_loss: 5.6283 - val_accuracy: 0.3928
# Epoch 113/200
# 400/400 [==============================] - 0s 445us/step - loss: 0.2303 - accuracy: 0.9141 - val_loss: 5.7113 - val_accuracy: 0.3908
# Epoch 114/200
# 400/400 [==============================] - 0s 446us/step - loss: 0.2767 - accuracy: 0.8929 - val_loss: 5.8739 - val_accuracy: 0.3788
# Epoch 115/200
# 400/400 [==============================] - 0s 444us/step - loss: 0.2525 - accuracy: 0.8997 - val_loss: 5.8677 - val_accuracy: 0.3928
# Epoch 116/200
# 400/400 [==============================] - 0s 445us/step - loss: 0.2694 - accuracy: 0.8976 - val_loss: 6.2959 - val_accuracy: 0.3848
# Epoch 117/200
# 400/400 [==============================] - 0s 445us/step - loss: 0.2629 - accuracy: 0.9012 - val_loss: 5.5785 - val_accuracy: 0.4148
# Epoch 118/200
# 400/400 [==============================] - 0s 444us/step - loss: 0.2502 - accuracy: 0.8987 - val_loss: 5.5033 - val_accuracy: 0.4188
# Epoch 119/200
# 400/400 [==============================] - 0s 446us/step - loss: 0.2034 - accuracy: 0.9244 - val_loss: 5.8130 - val_accuracy: 0.4108
# Epoch 120/200
# 400/400 [==============================] - 0s 446us/step - loss: 0.2578 - accuracy: 0.8987 - val_loss: 5.7350 - val_accuracy: 0.4068
# Epoch 121/200
# 400/400 [==============================] - 0s 447us/step - loss: 0.2237 - accuracy: 0.9128 - val_loss: 5.5751 - val_accuracy: 0.4148
# Epoch 122/200
# 400/400 [==============================] - 0s 445us/step - loss: 0.2567 - accuracy: 0.9089 - val_loss: 6.0052 - val_accuracy: 0.4168
# Epoch 123/200
# 400/400 [==============================] - 0s 446us/step - loss: 0.2380 - accuracy: 0.9115 - val_loss: 5.6526 - val_accuracy: 0.4028
# Epoch 124/200
# 400/400 [==============================] - 0s 445us/step - loss: 0.2505 - accuracy: 0.9095 - val_loss: 5.7237 - val_accuracy: 0.3908
# Epoch 125/200
# 400/400 [==============================] - 0s 445us/step - loss: 0.2064 - accuracy: 0.9197 - val_loss: 6.2896 - val_accuracy: 0.3908
# Epoch 126/200
# 400/400 [==============================] - 0s 446us/step - loss: 0.2507 - accuracy: 0.8982 - val_loss: 5.6404 - val_accuracy: 0.4489
# Epoch 127/200
# 400/400 [==============================] - 0s 445us/step - loss: 0.2541 - accuracy: 0.9047 - val_loss: 5.8446 - val_accuracy: 0.4248
# Epoch 128/200
# 400/400 [==============================] - 0s 451us/step - loss: 0.2164 - accuracy: 0.9201 - val_loss: 5.8252 - val_accuracy: 0.3908
# Epoch 129/200
# 400/400 [==============================] - 0s 448us/step - loss: 0.2420 - accuracy: 0.9068 - val_loss: 6.4778 - val_accuracy: 0.3868
# Epoch 130/200
# 400/400 [==============================] - 0s 447us/step - loss: 0.2347 - accuracy: 0.9100 - val_loss: 5.5103 - val_accuracy: 0.4028
# Epoch 131/200
# 400/400 [==============================] - 0s 448us/step - loss: 0.2243 - accuracy: 0.9158 - val_loss: 5.6263 - val_accuracy: 0.3908
# Epoch 132/200
# 400/400 [==============================] - 0s 448us/step - loss: 0.2243 - accuracy: 0.9162 - val_loss: 6.0705 - val_accuracy: 0.3988
# Epoch 133/200
# 400/400 [==============================] - 0s 448us/step - loss: 0.2426 - accuracy: 0.9060 - val_loss: 6.0216 - val_accuracy: 0.4108
# Epoch 134/200
# 400/400 [==============================] - 0s 449us/step - loss: 0.2056 - accuracy: 0.9250 - val_loss: 6.1839 - val_accuracy: 0.3848
# Epoch 135/200
# 400/400 [==============================] - 0s 453us/step - loss: 0.2155 - accuracy: 0.9176 - val_loss: 6.0561 - val_accuracy: 0.4148
# Epoch 136/200
# 400/400 [==============================] - 0s 450us/step - loss: 0.2708 - accuracy: 0.8913 - val_loss: 6.0100 - val_accuracy: 0.4068
# Epoch 137/200
# 400/400 [==============================] - 0s 447us/step - loss: 0.2330 - accuracy: 0.9130 - val_loss: 6.0964 - val_accuracy: 0.4289
# Epoch 138/200
# 400/400 [==============================] - 0s 449us/step - loss: 0.2288 - accuracy: 0.9150 - val_loss: 5.9864 - val_accuracy: 0.3928
# Epoch 139/200
# 400/400 [==============================] - 0s 447us/step - loss: 0.2244 - accuracy: 0.9127 - val_loss: 6.1942 - val_accuracy: 0.3948
# Epoch 140/200
# 400/400 [==============================] - 0s 454us/step - loss: 0.2557 - accuracy: 0.9066 - val_loss: 6.2833 - val_accuracy: 0.4088
# Epoch 141/200
# 400/400 [==============================] - 0s 449us/step - loss: 0.2281 - accuracy: 0.9144 - val_loss: 6.1089 - val_accuracy: 0.3988
# Epoch 142/200
# 400/400 [==============================] - 0s 447us/step - loss: 0.2633 - accuracy: 0.9064 - val_loss: 6.1766 - val_accuracy: 0.4008
# Epoch 143/200
# 400/400 [==============================] - 0s 454us/step - loss: 0.2110 - accuracy: 0.9221 - val_loss: 5.8966 - val_accuracy: 0.3868
# Epoch 144/200
# 400/400 [==============================] - 0s 451us/step - loss: 0.1876 - accuracy: 0.9299 - val_loss: 6.5367 - val_accuracy: 0.4128
# Epoch 145/200
# 400/400 [==============================] - 0s 486us/step - loss: 0.2956 - accuracy: 0.8980 - val_loss: 6.3323 - val_accuracy: 0.4289
# Epoch 146/200
# 400/400 [==============================] - 0s 453us/step - loss: 0.1838 - accuracy: 0.9263 - val_loss: 6.3572 - val_accuracy: 0.4269
# Epoch 147/200
# 400/400 [==============================] - 0s 452us/step - loss: 0.2427 - accuracy: 0.9078 - val_loss: 6.4146 - val_accuracy: 0.4108
# Epoch 148/200
# 400/400 [==============================] - 0s 449us/step - loss: 0.2419 - accuracy: 0.9048 - val_loss: 5.8197 - val_accuracy: 0.4349
# Epoch 149/200
# 400/400 [==============================] - 0s 441us/step - loss: 0.1995 - accuracy: 0.9234 - val_loss: 6.7555 - val_accuracy: 0.3487
# Epoch 150/200
# 400/400 [==============================] - 0s 445us/step - loss: 0.2460 - accuracy: 0.9059 - val_loss: 6.1441 - val_accuracy: 0.4028
# Epoch 151/200
# 400/400 [==============================] - 0s 445us/step - loss: 0.2299 - accuracy: 0.9137 - val_loss: 6.7889 - val_accuracy: 0.3968
# Epoch 152/200
# 400/400 [==============================] - 0s 441us/step - loss: 0.2092 - accuracy: 0.9236 - val_loss: 6.4741 - val_accuracy: 0.4309
# Epoch 153/200
# 400/400 [==============================] - 0s 446us/step - loss: 0.2316 - accuracy: 0.9177 - val_loss: 6.1976 - val_accuracy: 0.4108
# Epoch 154/200
# 400/400 [==============================] - 0s 460us/step - loss: 0.2068 - accuracy: 0.9251 - val_loss: 5.5120 - val_accuracy: 0.3928
# Epoch 155/200
# 400/400 [==============================] - 0s 463us/step - loss: 0.2198 - accuracy: 0.9143 - val_loss: 6.7703 - val_accuracy: 0.3747
# Epoch 156/200
# 400/400 [==============================] - 0s 454us/step - loss: 0.2131 - accuracy: 0.9163 - val_loss: 6.3650 - val_accuracy: 0.3968
# Epoch 157/200
# 400/400 [==============================] - 0s 458us/step - loss: 0.2558 - accuracy: 0.9017 - val_loss: 5.9057 - val_accuracy: 0.4389
# Epoch 158/200
# 400/400 [==============================] - 0s 453us/step - loss: 0.1962 - accuracy: 0.9299 - val_loss: 6.4001 - val_accuracy: 0.3828
# Epoch 159/200
# 400/400 [==============================] - 0s 451us/step - loss: 0.2099 - accuracy: 0.9244 - val_loss: 5.9759 - val_accuracy: 0.4188
# Epoch 160/200
# 400/400 [==============================] - 0s 456us/step - loss: 0.2387 - accuracy: 0.9119 - val_loss: 6.2331 - val_accuracy: 0.3747
# Epoch 161/200
# 400/400 [==============================] - 0s 456us/step - loss: 0.2056 - accuracy: 0.9169 - val_loss: 5.7323 - val_accuracy: 0.4188
# Epoch 162/200
# 400/400 [==============================] - 0s 455us/step - loss: 0.1933 - accuracy: 0.9283 - val_loss: 6.5124 - val_accuracy: 0.3928
# Epoch 163/200
# 400/400 [==============================] - 0s 499us/step - loss: 0.1881 - accuracy: 0.9274 - val_loss: 6.1126 - val_accuracy: 0.3888
# Epoch 164/200
# 400/400 [==============================] - 0s 471us/step - loss: 0.2194 - accuracy: 0.9201 - val_loss: 6.6345 - val_accuracy: 0.3948
# Epoch 165/200
# 400/400 [==============================] - 0s 463us/step - loss: 0.2737 - accuracy: 0.8992 - val_loss: 6.5966 - val_accuracy: 0.4048
# Epoch 166/200
# 400/400 [==============================] - 0s 460us/step - loss: 0.2495 - accuracy: 0.9105 - val_loss: 5.9225 - val_accuracy: 0.4048
# Epoch 167/200
# 400/400 [==============================] - 0s 463us/step - loss: 0.2056 - accuracy: 0.9198 - val_loss: 6.4668 - val_accuracy: 0.4028
# Epoch 168/200
# 400/400 [==============================] - 0s 460us/step - loss: 0.2076 - accuracy: 0.9219 - val_loss: 6.1116 - val_accuracy: 0.3948
# Epoch 169/200
# 400/400 [==============================] - 0s 459us/step - loss: 0.2025 - accuracy: 0.9257 - val_loss: 6.1998 - val_accuracy: 0.4068
# Epoch 170/200
# 400/400 [==============================] - 0s 458us/step - loss: 0.1750 - accuracy: 0.9349 - val_loss: 6.5517 - val_accuracy: 0.4128
# Epoch 171/200
# 400/400 [==============================] - 0s 462us/step - loss: 0.2479 - accuracy: 0.9048 - val_loss: 6.1269 - val_accuracy: 0.4008
# Epoch 172/200
# 400/400 [==============================] - 0s 455us/step - loss: 0.2178 - accuracy: 0.9192 - val_loss: 6.5046 - val_accuracy: 0.4168
# Epoch 173/200
# 400/400 [==============================] - 0s 459us/step - loss: 0.2021 - accuracy: 0.9270 - val_loss: 6.2331 - val_accuracy: 0.4429
# Epoch 174/200
# 400/400 [==============================] - 0s 454us/step - loss: 0.2026 - accuracy: 0.9208 - val_loss: 6.2731 - val_accuracy: 0.4188
# Epoch 175/200
# 400/400 [==============================] - 0s 461us/step - loss: 0.1952 - accuracy: 0.9258 - val_loss: 6.1374 - val_accuracy: 0.4269
# Epoch 176/200
# 400/400 [==============================] - 0s 457us/step - loss: 0.2176 - accuracy: 0.9286 - val_loss: 6.6735 - val_accuracy: 0.4048
# Epoch 177/200
# 400/400 [==============================] - 0s 464us/step - loss: 0.2337 - accuracy: 0.9124 - val_loss: 6.7189 - val_accuracy: 0.3888
# Epoch 178/200
# 400/400 [==============================] - 0s 464us/step - loss: 0.2156 - accuracy: 0.9146 - val_loss: 7.0284 - val_accuracy: 0.4409
# Epoch 179/200
# 400/400 [==============================] - 0s 462us/step - loss: 0.1787 - accuracy: 0.9311 - val_loss: 6.7815 - val_accuracy: 0.4088
# Epoch 180/200
# 400/400 [==============================] - 0s 455us/step - loss: 0.1914 - accuracy: 0.9262 - val_loss: 6.7812 - val_accuracy: 0.3587
# Epoch 181/200
# 400/400 [==============================] - 0s 455us/step - loss: 0.2283 - accuracy: 0.9192 - val_loss: 6.6399 - val_accuracy: 0.4208
# Epoch 182/200
# 400/400 [==============================] - 0s 450us/step - loss: 0.2034 - accuracy: 0.9241 - val_loss: 6.9541 - val_accuracy: 0.4128
# Epoch 183/200
# 400/400 [==============================] - 0s 452us/step - loss: 0.1861 - accuracy: 0.9279 - val_loss: 6.2309 - val_accuracy: 0.4148
# Epoch 184/200
# 400/400 [==============================] - 0s 452us/step - loss: 0.2816 - accuracy: 0.9026 - val_loss: 6.2055 - val_accuracy: 0.4369
# Epoch 185/200
# 400/400 [==============================] - 0s 449us/step - loss: 0.1875 - accuracy: 0.9323 - val_loss: 6.6578 - val_accuracy: 0.4188
# Epoch 186/200
# 400/400 [==============================] - 0s 454us/step - loss: 0.2020 - accuracy: 0.9238 - val_loss: 6.5216 - val_accuracy: 0.4028
# Epoch 187/200
# 400/400 [==============================] - 0s 457us/step - loss: 0.1873 - accuracy: 0.9296 - val_loss: 6.6431 - val_accuracy: 0.4048
# Epoch 188/200
# 400/400 [==============================] - 0s 471us/step - loss: 0.2226 - accuracy: 0.9162 - val_loss: 6.7007 - val_accuracy: 0.3888
# Epoch 189/200
# 400/400 [==============================] - 0s 469us/step - loss: 0.2150 - accuracy: 0.9161 - val_loss: 6.4192 - val_accuracy: 0.3968
# Epoch 190/200
# 400/400 [==============================] - 0s 468us/step - loss: 0.2149 - accuracy: 0.9192 - val_loss: 7.8885 - val_accuracy: 0.3768
# Epoch 191/200
# 400/400 [==============================] - 0s 465us/step - loss: 0.3941 - accuracy: 0.8863 - val_loss: 6.6595 - val_accuracy: 0.3808
# Epoch 192/200
# 400/400 [==============================] - 0s 464us/step - loss: 0.1561 - accuracy: 0.9420 - val_loss: 6.4946 - val_accuracy: 0.4028
# Epoch 193/200
# 400/400 [==============================] - 0s 471us/step - loss: 0.2018 - accuracy: 0.9196 - val_loss: 8.1229 - val_accuracy: 0.3848
# Epoch 194/200
# 400/400 [==============================] - 0s 472us/step - loss: 0.2388 - accuracy: 0.9111 - val_loss: 7.4549 - val_accuracy: 0.4228
# Epoch 195/200
# 400/400 [==============================] - 0s 470us/step - loss: 0.1862 - accuracy: 0.9317 - val_loss: 6.2654 - val_accuracy: 0.4269
# Epoch 196/200
# 400/400 [==============================] - 0s 467us/step - loss: 0.2153 - accuracy: 0.9144 - val_loss: 7.0507 - val_accuracy: 0.3888
# Epoch 197/200
# 400/400 [==============================] - 0s 464us/step - loss: 0.1614 - accuracy: 0.9405 - val_loss: 6.6175 - val_accuracy: 0.3928
# Epoch 198/200
# 400/400 [==============================] - 0s 462us/step - loss: 0.1892 - accuracy: 0.9295 - val_loss: 7.4166 - val_accuracy: 0.3627
# Epoch 199/200
# 400/400 [==============================] - 0s 462us/step - loss: 0.1757 - accuracy: 0.9379 - val_loss: 7.5213 - val_accuracy: 0.4168
# Epoch 200/200
# 400/400 [==============================] - 0s 470us/step - loss: 0.1960 - accuracy: 0.9236 - val_loss: 7.4463 - val_accuracy: 0.3848

# %%
histories
# Out:
# [(0,
#   <tensorflow.python.keras.callbacks.History at 0x29d6f06d0>,
#   <tensorflow.python.keras.engine.sequential.Sequential at 0x12f32d0d0>),
#  (1,
#   <tensorflow.python.keras.callbacks.History at 0x17505c2e0>,
#   <tensorflow.python.keras.engine.sequential.Sequential at 0x2a2d60d60>),
#  (2,
#   <tensorflow.python.keras.callbacks.History at 0x2a2a77e50>,
#   <tensorflow.python.keras.engine.sequential.Sequential at 0x104d8b850>),
#  (3,
#   <tensorflow.python.keras.callbacks.History at 0x2a7592c10>,
#   <tensorflow.python.keras.engine.sequential.Sequential at 0x2a2d74190>),
#  (4,
#   <tensorflow.python.keras.callbacks.History at 0x29bd09ac0>,
#   <tensorflow.python.keras.engine.sequential.Sequential at 0x2a2a13dc0>)]

# %%
summary_history = dict({'loss':[], 'accuracy':[], 'val_loss':[], 'val_accuracy':[]})
for h in histories:
    summary_history['loss'].append(h[1].history['loss'][-1])
    summary_history['accuracy'].append(h[1].history['accuracy'][-1])
    summary_history['val_loss'].append(h[1].history['val_loss'][-1]) 
    summary_history['val_accuracy'].append(h[1].history['val_accuracy'][-1])
summary_history = pd.DataFrame(summary_history)
summary_history
# Out:
#        loss  accuracy   val_loss  val_accuracy
# 0  0.215449  0.922835  11.362704       0.30500
# 1  0.163434  0.938840   8.439971       0.36000
# 2  0.206258  0.921978   8.795877       0.34200
# 3  0.154623  0.941983  10.971478       0.34600
# 4  0.205071  0.924250   7.446282       0.38477

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

# %%
fig, axs = plt.subplots(5, 2,figsize=(15,15))
fig.tight_layout(pad=2.0)
for h, i in zip(histories, range(len(histories))):
    axs[i, 0].plot(h[1].history['loss'])
    axs[i, 0].plot(h[1].history['val_loss'])
    axs[i, 0].set_title(f'Loss {i}')
    axs[i, 0].annotate(str(round(h[1].history['loss'][-1], 2)),
                       xy = (199, h[1].history['loss'][-1]),
                       xytext = (199, h[1].history['loss'][-1] + 0.1))
    axs[i, 0].annotate(str(round(h[1].history['val_loss'][-1], 2)),
                       xy = (199, h[1].history['val_loss'][-1]),
                       xytext = (199, h[1].history['val_loss'][-1] - 0.1))
    axs[0, 0].legend(['train', 'validation'], loc='upper left')
    axs[i, 1].plot(h[1].history['accuracy'])
    axs[i, 1].plot(h[1].history['val_accuracy'])
    axs[i, 1].set_title(f'Accuracy {i}')
    axs[i, 1].annotate(str(round(h[1].history['accuracy'][-1], 2)),
                       xy = (199, h[1].history['accuracy'][-1]),
                       xytext = (199, h[1].history['accuracy'][-1] - 0.01))
    axs[i, 1].annotate(str(round(h[1].history['val_accuracy'][-1], 2)),
                       xy = (199, h[1].history['val_accuracy'][-1]),
                       xytext = (199, h[1].history['val_accuracy'][-1] + 0.01))

# %%
fig.savefig('mean_data.pdf')

# %%
#best model: highest validation accuracy
best_model_index = summary_history['val_accuracy'].idxmax()
best_model = histories[best_model_index][2]
best_model.save('mean_data')
# Out:
# WARNING:tensorflow:AutoGraph could not transform <function canonicalize_signatures.<locals>.signature_wrapper at 0x2b300de50> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: unsupported operand type(s) for -: 'NoneType' and 'int'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function canonicalize_signatures.<locals>.signature_wrapper at 0x2b300de50> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: unsupported operand type(s) for -: 'NoneType' and 'int'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:FOR KERAS USERS: The object that you are saving contains one or more Keras models or layers. If you are loading the SavedModel with `tf.keras.models.load_model`, continue reading (otherwise, you may ignore the following instructions). Please change your code to save with `tf.keras.models.save_model` or `model.save`, and confirm that the file "keras.metadata" exists in the export directory. In the future, Keras will only load the SavedModels that have this file. In other words, `tf.saved_model.save` will no longer write SavedModels that can be recovered as Keras models (this will apply in TF 2.5).
#
# FOR DEVS: If you are overwriting _tracking_metadata in your class, this property has been used to save metadata in the SavedModel. The metadta field will be deprecated soon, so please move the metadata to a different file.
# INFO:tensorflow:Assets written to: mean_data/assets
# /Users/lizzy/miniforge3/envs/tf_m1/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py:2325: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# 2021-08-30 20:08:46.128212: W tensorflow/python/util/util.cc:348] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# /Users/lizzy/miniforge3/envs/tf_m1/lib/python3.8/site-packages/tensorflow/python/keras/engine/base_layer.py:1397: UserWarning: `layer.updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`layer.updates` will be removed in a future version. '

# %% [markdown]
# # Test

# %%
test_folds = [5,7,8,9,10]
features = ['mfcc', 'spectogram', 'mel_spectogram', 'chroma_stft', 'chroma_cqt', 'chroma_cens', 'spectral_contrast', 'tonnetz', 'rms', 'spectral_centroid', 'spectral_bandwidth', 'spectral_flatness', 'poly_features', 'zero_crossing_rate', 'spectral_rolloff']

# %%
n_features = 0
feature_matrices = []
for feature in tqdm_notebook(features, desc = "Features loop"):
    feature_matrix = np.load(f'/Users/lizzy/Desktop/Universita/cesab/project/all_data/test_data/{feature}_matrix.npy')
    n_observations = feature_matrix.shape[0]
    if len(feature_matrix.shape) > 2:
        n_features = n_features + feature_matrix.shape[1]
    else:
        n_features = n_features + 1
        n_samples = feature_matrix.shape[1]
    feature_matrices.append(feature_matrix)
# Out:
# Features loop:   0%|          | 0/15 [00:00<?, ?it/s]

# %%
X_test = np.ndarray(shape = (n_observations, n_features))

# %%
for feature_matrix in tqdm_notebook(feature_matrices, desc = "Features loop"):
    for i in range(X_test.shape[0]):
        feature_count = 0
        if len(feature_matrix.shape) > 2:
            for j in range(feature_matrix.shape[1]):
                X_test[i, feature_count] = np.mean(feature_matrix[i, j])
                feature_count = feature_count + 1
        else:
            X_test[i, feature_count] = np.mean(feature_matrix[i])
            feature_count = feature_count + 1
# Out:
# Features loop:   0%|          | 0/15 [00:00<?, ?it/s]

# %%
y_test = np.load('/Users/lizzy/Desktop/Universita/cesab/project/all_data/test_data/test_class.json.npy')

# %%
model =  tensorflow.keras.models.load_model("mean_data")

# %%
evaluation = model.evaluate(X_test, y_test)
# Out:
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x4535c6280> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: unsupported operand type(s) for -: 'NoneType' and 'int'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x4535c6280> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: unsupported operand type(s) for -: 'NoneType' and 'int'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 133/133 [==============================] - 0s 311us/step - loss: 9.6392 - accuracy: 0.3948
# 2021-08-30 20:11:37.527083: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2021-08-30 20:11:37.527223: W tensorflow/core/platform/profile_utils/cpu_utils.cc:126] Failed to get CPU frequency: 0 Hz

# %%
print(f'Loss: {evaluation[0]}, accuracy:{evaluation[1]}')
# Out:
# Loss: 9.639188766479492, accuracy:0.394755482673645
